# %%
import os
import sys
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier, RadiusNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn.grid_search import GridSearchCV

# %%
train = pd.read_csv('train.csv')
train.set_index(train['PassengerId'],inplace=True)
train.head().T
# Out:
# PassengerId                        1  \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                               22
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
# PassengerId                                                  2  \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                         38
# SibSp                                                        1
# Parch                                                        0
# Ticket                                                PC 17599
# Fare                                                   71.2833
# Cabin                                                      C85
# Embarked                                                     C
#
# PassengerId                       3  \
# PassengerId                       3
# Survived                          1
# Pclass                            3
# Name         Heikkinen, Miss. Laina
# Sex                          female
# Age                              26
# SibSp                             0
# Parch                             0
# Ticket             STON/O2. 3101282
# Fare                          7.925
# Cabin                           NaN
# Embarked                          S
#
# PassengerId                                             4  \
# PassengerId                                             4
# Survived                                                1
# Pclass                                                  1
# Name         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                female
# Age                                                    35
# SibSp                                                   1
# Parch                                                   0
# Ticket                                             113803
# Fare                                                 53.1
# Cabin                                                C123
# Embarked                                                S
#
# PassengerId                         5
# PassengerId                         5
# Survived                            0
# Pclass                              3
# Name         Allen, Mr. William Henry
# Sex                              male
# Age                                35
# SibSp                               0
# Parch                               0
# Ticket                         373450
# Fare                             8.05
# Cabin                             NaN
# Embarked                            S

# %% [markdown]
# ## clean up the data

# %%
print len(train)
print sum(list(train.groupby('Sex').size()))
train.groupby('Sex').size()
# Out:
# 891
# 891
# Sex
# female    314
# male      577
# dtype: int64

# %%
def clean_titanic_data(df):
    #clean embarked
    df['Embarked'] = df['Embarked'].apply(lambda x: 0 if x=='Q' else x)
    df['Embarked'] = df['Embarked'].apply(lambda x: 1 if x=='S' else x)
    df['Embarked'] = df['Embarked'].apply(lambda x: 2 if x=='C' else x)
    df['Embarked'] = df['Embarked'].fillna('3')
    #clean age
    avg_age = np.average(df[(df['Age'].notnull())]['Age'])
    print "avg age: ",avg_age
    df['Age'] = df['Age'].fillna(avg_age)
    #clean fare
    avg_fare = np.average(df[(df['Fare'].notnull())]['Fare'])
    print "avg Fare: ",avg_fare
    df['Fare'] = df['Fare'].fillna(avg_fare)
    #turn sex to number
    df['Sex'] = df['Sex'].apply(lambda x: 0 if x=='female' else 1)
    df['Sex'] = df['Sex'].fillna(2)
    #drop other stuff while testing
    df.drop(['Name', 'PassengerId', 'Ticket', 'Cabin'], axis=1, inplace=True)
    
    return df

# %%
clean_train = clean_titanic_data(train)
# Out:
# avg age:  29.6991176471
# avg Fare:  32.2042079686

# %%
clean_train.head().T
# Out:
# PassengerId     1        2      3     4     5
# Survived        0        1      1     1     0
# Pclass          3        1      3     1     3
# Sex             1        0      0     0     1
# Age            22       38     26    35    35
# SibSp           1        1      0     1     0
# Parch           0        0      0     0     0
# Fare         7.25  71.2833  7.925  53.1  8.05
# Embarked        1        2      1     1     1

# %% [markdown]
# ## test out some stuff

# %%
clean_train_y = clean_train[[0]]
clean_train.drop(['Survived'], axis=1, inplace=True)
df_train_index, df_test_index = train_test_split(clean_train.index, test_size=0.35)
df_test_x = clean_train.loc[df_test_index]
df_train_x = clean_train.loc[df_train_index]
df_test_y = clean_train_y.loc[df_test_index]
df_train_y = clean_train_y.loc[df_train_index]

# %%
df_train_y.head().T
# Out:
# PassengerId  761  891  78   16   499
# Survived       0    0    0    1    0

# %%
df_train_x.head().T
# Out:
# PassengerId       761   891       78  16      499
# Pclass              3     3         3   2       1
# Sex                 1     1         1   0       0
# Age          29.69912    32  29.69912  55      25
# SibSp               0     0         0   0       1
# Parch               0     0         0   0       2
# Fare             14.5  7.75      8.05  16  151.55
# Embarked            1     0         1   1       1

# %%
estimator = GradientBoostingClassifier()
param_grid = dict(loss = ['deviance', 'exponential'], 
                  n_estimators = [10,25,50,100], 
                  max_features = [None,'auto'], 
                  max_depth = [2,3,5], 
                  min_samples_split = [2,10,25]
                 )


# http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# estimator = RandomForestClassifier()
# param_grid = dict(n_estimators = [10,25,50,100], max_features=[None], class_weight = ['subsample','auto'],
#                  criterion = ['gini','entropy'], max_depth = [2,3,5], min_samples_split = [2,10,25])

# estimator = ExtraTreesClassifier()
# param_grid = dict(n_estimators = [10,25,50,100], max_features=[None], class_weight = ['subsample','auto'],
#                  criterion = ['gini','entropy'], max_depth = [2,3,5], min_samples_split = [2,10,25])


grid_search = GridSearchCV(estimator, param_grid = param_grid, cv = 2, n_jobs=1, verbose=0)

# %%
grid_search.fit(df_train_x,df_train_y['Survived'])
# Out:
# Fitting 2 folds for each of 144 candidates, totalling 288 fits
# [CV] max_features=None, loss=deviance, min_samples_split=2, n_estimators=10, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=2, n_estimators=10, max_depth=2, score=0.803448 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=2, n_estimators=10, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=2, n_estimators=10, max_depth=2, score=0.806228 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=2, n_estimators=25, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=2, n_estimators=25, max_depth=2, score=0.813793 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=2, n_estimators=25, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=2, n_estimators=25, max_depth=2, score=0.816609 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=2, n_estimators=50, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=2, n_estimators=50, max_depth=2, score=0.831034 -   0.1s
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   2 jobs       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   5 jobs       | elapsed:    0.1s
# [CV] max_features=None, loss=deviance, min_samples_split=2, n_estimators=50, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=2, n_estimators=50, max_depth=2, score=0.813149 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=2, n_estimators=100, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=2, n_estimators=100, max_depth=2, score=0.817241 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=2, n_estimators=100, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=2, n_estimators=100, max_depth=2, score=0.813149 -   0.1s
# [CV] max_features=None, loss=deviance, min_samples_split=10, n_estimators=10, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=10, n_estimators=10, max_depth=2, score=0.803448 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=10, n_estimators=10, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=10, n_estimators=10, max_depth=2, score=0.806228 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=10, n_estimators=25, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=10, n_estimators=25, max_depth=2, score=0.813793 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=10, n_estimators=25, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=10, n_estimators=25, max_depth=2, score=0.816609 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=10, n_estimators=50, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=10, n_estimators=50, max_depth=2, score=0.831034 -   0.1s
# [Parallel(n_jobs=1)]: Done   8 jobs       | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done  13 jobs       | elapsed:    0.4s
# [CV] max_features=None, loss=deviance, min_samples_split=10, n_estimators=50, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=10, n_estimators=50, max_depth=2, score=0.813149 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=10, n_estimators=100, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=10, n_estimators=100, max_depth=2, score=0.813793 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=10, n_estimators=100, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=10, n_estimators=100, max_depth=2, score=0.816609 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=25, n_estimators=10, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=25, n_estimators=10, max_depth=2, score=0.803448 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=25, n_estimators=10, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=25, n_estimators=10, max_depth=2, score=0.806228 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=25, n_estimators=25, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=25, n_estimators=25, max_depth=2, score=0.813793 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=25, n_estimators=25, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=25, n_estimators=25, max_depth=2, score=0.809689 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=25, n_estimators=50, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=25, n_estimators=50, max_depth=2, score=0.834483 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=25, n_estimators=50, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=25, n_estimators=50, max_depth=2, score=0.813149 -   0.0s
# [CV] max_features=None, loss=deviance, min_samples_split=25, n_estimators=100, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=25, n_estimators=100, max_depth=2, score=0.820690 -   0.1s
# [Parallel(n_jobs=1)]: Done  18 jobs       | elapsed:    0.5s
# [Parallel(n_jobs=1)]: Done  25 jobs       | elapsed:    0.7s
# [CV] max_features=None, loss=deviance, min_samples_split=25, n_estimators=100, max_depth=2
# [CV]  max_features=None, loss=deviance, min_samples_split=25, n_estimators=100, max_depth=2, score=0.813149 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=2, n_estimators=10, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=2, n_estimators=10, max_depth=2, score=0.803448 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=2, n_estimators=10, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=2, n_estimators=10, max_depth=2, score=0.813149 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=2, n_estimators=25, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=2, n_estimators=25, max_depth=2, score=0.813793 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=2, n_estimators=25, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=2, n_estimators=25, max_depth=2, score=0.816609 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=2, n_estimators=50, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=2, n_estimators=50, max_depth=2, score=0.824138 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=2, n_estimators=50, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=2, n_estimators=50, max_depth=2, score=0.799308 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=2, n_estimators=100, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=2, n_estimators=100, max_depth=2, score=0.820690 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=2, n_estimators=100, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=2, n_estimators=100, max_depth=2, score=0.813149 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=10, n_estimators=10, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=10, n_estimators=10, max_depth=2, score=0.793103 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=10, n_estimators=10, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=10, n_estimators=10, max_depth=2, score=0.799308 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=10, n_estimators=25, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=10, n_estimators=25, max_depth=2, score=0.810345 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=10, n_estimators=25, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=10, n_estimators=25, max_depth=2, score=0.795848 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=10, n_estimators=50, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=10, n_estimators=50, max_depth=2, score=0.824138 -   0.0s
# [CV] max_features=auto, loss=deviance, min_samples_split=10, n_estimators=50, max_depth=2
# [CV]  max_features=auto, loss=deviance, min_samples_split=10, n_estimators=50, max_depth

# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=10, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=10, max_depth=3, score=0.820690 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=10, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=10, max_depth=3, score=0.802768 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=25, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=25, max_depth=3, score=0.824138 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=25, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=25, max_depth=3, score=0.813149 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=50, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=50, max_depth=3, score=0.827586 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=50, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=50, max_depth=3, score=0.820069 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=100, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=100, max_depth=3, score=0.803448 -   0.1s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=100, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=100, max_depth=3, score=0.806228 -   0.1s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=10, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=10, max_depth=3, score=0.793103 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=10, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=10, max_depth=3, score=0.792388 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=25, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=25, max_depth=3, score=0.813793 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=25, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=25, max_depth=3, score=0.826990 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=50, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=50, max_depth=3, score=0.817241 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=50, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=50, max_depth=3, score=0.826990 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=100, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=100, max_depth=3, score=0.786207 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=100, max_depth=3
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=100, max_depth=3, score=0.809689 -   0.1s
# [CV] max_features=None, loss=exponential, min_samples_split=2, n_estimators=10, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=2, n_estimators=10, max_depth=5, score=0.800000 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=2, n_estimators=10, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=2, n_estimators=10, max_depth=5, score=0.788927 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=2, n_estimators=25, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=2, n_estimators=25, max_depth=5, score=0.803448 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=2, n_estimators=25, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=2, n_estimators=25, max_depth=5, score=0.799308 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=2, n_estimators=50, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=2, n_estimators=50, max_depth=5, score=0.806897 -   0.1s
# [CV] max_features=None, loss=exponential, min_samples_split=2, n_estimators=50, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=2, n_estimators=50, max_depth=5, score=0.792388 -   0.1s
# [CV] max_features=None, loss=exponential, min_samples_split=2, n_estimators=100, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=2, n_estimators=100, max_depth=5, score=0.796552 -   0.1s
# [CV] max_features=None, loss=exponential, min_samples_split=2, n_estimators=100, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=2, n_estimators=100, max_depth=5, score=0.820069 -   0.1s
# [CV] max_features=None, loss=exponential, min_samples_split=10, n_estimators=10, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=10, n_estimators=10, max_depth=5, score=0.810345 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=10, n_estimators=10, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=10, n_estimators=10, max_depth=5, score=0.806228 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=10, n_estimators=25, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=10, n_estimators=25, max_depth=5, score=0.803448 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=10, n_estimators=25, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=10, n_estimators=25, max_depth=5, score=0.809689 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=10, n_estimators=50, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=10, n_estimators=50, max_depth=5, score=0.806897 -   0.1s
# [CV] max_features=None, loss=exponential, min_samples_split=10, n_estimators=50, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=10, n_estimators=50, max_depth=5, score=0.816609 -   0.1s
# [CV] max_features=None, loss=exponential, min_samples_split=10, n_estimators=100, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=10, n_estimators=100, max_depth=5, score=0.796552 -   0.1s
# [CV] max_features=None, loss=exponential, min_samples_split=10, n_estimators=100, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=10, n_estimators=100, max_depth=5, score=0.809689 -   0.1s
# [CV] max_features=None, loss=exponential, min_samples_split=25, n_estimators=10, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=25, n_estimators=10, max_depth=5, score=0.820690 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=25, n_estimators=10, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=25, n_estimators=10, max_depth=5, score=0.813149 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=25, n_estimators=25, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=25, n_estimators=25, max_depth=5, score=0.831034 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=25, n_estimators=25, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=25, n_estimators=25, max_depth=5, score=0.823529 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=25, n_estimators=50, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=25, n_estimators=50, max_depth=5, score=0.806897 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=25, n_estimators=50, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=25, n_estimators=50, max_depth=5, score=0.816609 -   0.0s
# [CV] max_features=None, loss=exponential, min_samples_split=25, n_estimators=100, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=25, n_estimators=100, max_depth=5, score=0.793103 -   0.1s
# [CV] max_features=None, loss=exponential, min_samples_split=25, n_estimators=100, max_depth=5
# [CV]  max_features=None, loss=exponential, min_samples_split=25, n_estimators=100, max_depth=5, score=0.833910 -   0.1s
# [Parallel(n_jobs=1)]: Done 242 jobs       | elapsed:    7.6s
# [Parallel(n_jobs=1)]: Done 265 jobs       | elapsed:    8.9s
# [CV] max_features=auto, loss=exponential, min_samples_split=2, n_estimators=10, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=2, n_estimators=10, max_depth=5, score=0.806897 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=2, n_estimators=10, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=2, n_estimators=10, max_depth=5, score=0.816609 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=2, n_estimators=25, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=2, n_estimators=25, max_depth=5, score=0.806897 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=2, n_estimators=25, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=2, n_estimators=25, max_depth=5, score=0.833910 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=2, n_estimators=50, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=2, n_estimators=50, max_depth=5, score=0.793103 -   0.2s
# [CV] max_features=auto, loss=exponential, min_samples_split=2, n_estimators=50, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=2, n_estimators=50, max_depth=5, score=0.809689 -   0.1s
# [CV] max_features=auto, loss=exponential, min_samples_split=2, n_estimators=100, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=2, n_estimators=100, max_depth=5, score=0.810345 -   0.3s
# [CV] max_features=auto, loss=exponential, min_samples_split=2, n_estimators=100, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=2, n_estimators=100, max_depth=5, score=0.806228 -   0.3s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=10, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=10, max_depth=5, score=0.813793 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=10, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=10, max_depth=5, score=0.820069 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=25, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=25, max_depth=5, score=0.803448 -   0.1s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=25, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=25, max_depth=5, score=0.823529 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=50, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=50, max_depth=5, score=0.789655 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=50, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=50, max_depth=5, score=0.799308 -   0.1s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=100, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=100, max_depth=5, score=0.806897 -   0.1s
# [CV] max_features=auto, loss=exponential, min_samples_split=10, n_estimators=100, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=10, n_estimators=100, max_depth=5, score=0.792388 -   0.1s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=10, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=10, max_depth=5, score=0.789655 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=10, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=10, max_depth=5, score=0.809689 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=25, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=25, max_depth=5, score=0.806897 -   0.1s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=25, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=25, max_depth=5, score=0.820069 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=50, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=50, max_depth=5, score=0.803448 -   0.0s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=50, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=50, max_depth=5, score=0.833910 -   0.1s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=100, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=100, max_depth=5, score=0.789655 -   0.1s
# [CV] max_features=auto, loss=exponential, min_samples_split=25, n_estimators=100, max_depth=5
# [CV]  max_features=auto, loss=exponential, min_samples_split=25, n_estimators=100, max_depth=5, score=0.806228 -   0.1s
# [Parallel(n_jobs=1)]: Done 288 jobs       | elapsed:   10.7s
# [Parallel(n_jobs=1)]: Done 288 out of 288 | elapsed:   10.7s finished
# GridSearchCV(cv=2, error_score='raise',
#        estimator=GradientBoostingClassifier(init=None, learning_rate=0.1, loss='deviance',
#               max_depth=3, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               random_state=None, subsample=1.0, verbose=0,
#               warm_start=False),
#        fit_params={}, iid=True, loss_func=None, n_jobs=1,
#        param_grid={'min_samples_split': [2, 10, 25], 'max_features': [None, 'auto'], 'n_estimators': [10, 25, 50, 100], 'max_depth': [2, 3, 5], 'loss': ['deviance', 'exponential']},
#        pre_dispatch='2*n_jobs', refit=True, score_func=None, scoring=None,
#        verbose=10)

# %%
best_estimator = grid_search.best_estimator_
best_estimator.fit(df_train_x,df_train_y['Survived'])
# Out:
# GradientBoostingClassifier(init=None, learning_rate=0.1, loss='deviance',
#               max_depth=3, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=10,
#               min_weight_fraction_leaf=0.0, n_estimators=25,
#               random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
train_score = best_estimator.score(df_train_x,df_train_y['Survived'])
test_score = best_estimator.score(df_test_x,df_test_y['Survived'])
print "train: ",train_score
print " test: ",test_score
# Out:
# train:  0.865284974093
#  test:  0.814102564103

# %%
str(type(best_estimator)).split('.')[-1][0:-2]
# Out:
# 'GradientBoostingClassifier'

# %% [markdown]
# ## import test, score, output

# %%
test = pd.read_csv('test.csv')
test.set_index(test['PassengerId'],inplace=True)
clean_test = clean_titanic_data(test)
# Out:
# avg age:  30.2725903614
# avg Fare:  35.6271884892

# %%
clean_test.head().T
# Out:
# PassengerId      892  893      894      895      896
# Pclass        3.0000    3   2.0000   3.0000   3.0000
# Sex           1.0000    0   1.0000   1.0000   0.0000
# Age          34.5000   47  62.0000  27.0000  22.0000
# SibSp         0.0000    1   0.0000   0.0000   1.0000
# Parch         0.0000    0   0.0000   0.0000   1.0000
# Fare          7.8292    7   9.6875   8.6625  12.2875
# Embarked      0.0000    1   0.0000   1.0000   1.0000

# %%
output = best_estimator.predict_proba(clean_test)
output
# Out:
# array([[ 0.87167897,  0.12832103],
#        [ 0.60262279,  0.39737721],
#        [ 0.86064927,  0.13935073],
#        [ 0.86064927,  0.13935073],
#        [ 0.39372165,  0.60627835],
#        [ 0.84162161,  0.15837839],
#        [ 0.39818017,  0.60181983],
#        [ 0.75097817,  0.24902183],
#        [ 0.32149829,  0.67850171],
#        [ 0.83378748,  0.16621252],
#        [ 0.87167897,  0.12832103],
#        [ 0.79084015,  0.20915985],
#        [ 0.10136003,  0.89863997],
#        [ 0.846886  ,  0.153114  ],
#        [ 0.0857372 ,  0.9142628 ],
#        [ 0.1050949 ,  0.8949051 ],
#        [ 0.83729032,  0.16270968],
#        [ 0.8221596 ,  0.1778404 ],
#        [ 0.44235959,  0.55764041],
#        [ 0.58000441,  0.41999559],
#        [ 0.67168926,  0.32831074],
#        [ 0.23751254,  0.76248746],
#        [ 0.0857372 ,  0.9142628 ],
#        [ 0.65045985,  0.34954015],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.84800935,  0.15199065],
#        [ 0.09909903,  0.90090097],
#        [ 0.8221596 ,  0.1778404 ],
#        [ 0.6944744 ,  0.3055256 ],
#        [ 0.81232261,  0.18767739],
#        [ 0.83378748,  0.16621252],
#        [ 0.75097817,  0.24902183],
#        [ 0.35252016,  0.64747984],
#        [ 0.71387655,  0.28612345],
#        [ 0.60391362,  0.39608638],
#        [ 0.78854481,  0.21145519],
#        [ 0.44235959,  0.55764041],
#        [ 0.57526665,  0.42473335],
#        [ 0.86064927,  0.13935073],
#        [ 0.64534078,  0.35465922],
#        [ 0.81617808,  0.18382192],
#        [ 0.6944744 ,  0.3055256 ],
#        [ 0.87167897,  0.12832103],

#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.86294756,  0.13705244],
#        [ 0.87167897,  0.12832103],
#        [ 0.35252016,  0.64747984],
#        [ 0.86294756,  0.13705244],
#        [ 0.31228846,  0.68771154],
#        [ 0.83729032,  0.16270968],
#        [ 0.85374939,  0.14625061],
#        [ 0.85374939,  0.14625061],
#        [ 0.67600318,  0.32399682],
#        [ 0.71387655,  0.28612345],
#        [ 0.83298663,  0.16701337],
#        [ 0.87167897,  0.12832103],
#        [ 0.86294756,  0.13705244],
#        [ 0.8221596 ,  0.1778404 ],
#        [ 0.83729032,  0.16270968],
#        [ 0.44235959,  0.55764041],
#        [ 0.75097817,  0.24902183],
#        [ 0.83784756,  0.16215244],
#        [ 0.0857372 ,  0.9142628 ],
#        [ 0.61136441,  0.38863559],
#        [ 0.83378748,  0.16621252],
#        [ 0.6944744 ,  0.3055256 ],
#        [ 0.82065033,  0.17934967],
#        [ 0.6944744 ,  0.3055256 ],
#        [ 0.85374939,  0.14625061],
#        [ 0.6944744 ,  0.3055256 ],
#        [ 0.83378748,  0.16621252],
#        [ 0.09909903,  0.90090097],
#        [ 0.83298663,  0.16701337],
#        [ 0.76879294,  0.23120706],
#        [ 0.4101965 ,  0.5898035 ],
#        [ 0.81207256,  0.18792744],
#        [ 0.86294756,  0.13705244],
#        [ 0.0857372 ,  0.9142628 ],
#        [ 0.44235959,  0.55764041],
#        [ 0.6944744 ,  0.3055256 ],
#        [ 0.39372165,  0.60627835],
#        [ 0.39818017,  0.60181983],
#        [ 0.19271525,  0.80728475],
#        [ 0.12990753,  0.87009247],
#        [ 0.87167897,  0.12832103],
#        [ 0.83729032,  0.16270968],
#        [ 0.35252016,  0.64747984],
#        [ 0.67600318,  0.32399682],
#        [ 0.73821368,  0.26178632],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.57526665,  0.42473335],
#        [ 0.87167897,  0.12832103],
#        [ 0.8221596 ,  0.1778404 ],
#        [ 0.74790466,  0.25209534],
#        [ 0.83298663,  0.16701337],
#        [ 0.75097817,  0.24902183],
#        [ 0.10747638,  0.89252362],
#        [ 0.10747638,  0.89252362],
#        [ 0.62634608,  0.37365392],
#        [ 0.0910063 ,  0.9089937 ],
#        [ 0.14900578,  0.85099422],
#        [ 0.83729032,  0.16270968],
#        [ 0.65045985,  0.34954015],
#        [ 0.10136003,  0.89863997],
#        [ 0.87167897,  0.12832103],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.83378748,  0.16621252],
#        [ 0.11124749,  0.88875251],
#        [ 0.81248306,  0.18751694],
#        [ 0.85349917,  0.14650083],
#        [ 0.83729032,  0.16270968],
#        [ 0.83378748,  0.16621252],
#        [ 0.79084015,  0.20915985],
#        [ 0.54886176,  0.45113824],
#        [ 0.8501624 ,  0.1498376 ],
#        [ 0.20639319,  0.79360681],
#        [ 0.87167897,  0.12832103],
#        [ 0.10968665,  0.89031335],
#        [ 0.38638105,  0.61361895],
#        [ 0.84641365,  0.15358635],
#        [ 0.44235959,  0.55764041],
#        [ 0.31228846,  0.68771154],
#        [ 0.17225776,  0.82774224],
#        [ 0.59705523,  0.40294477],
#        [ 0.09972354,  0.90027646],
#        [ 0.84641365,  0.15358635],
#        [ 0.79466921,  0.20533079],
#        [ 0.39818017,  0.60181983],
#        [ 0.84641365,  0.15358635],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.86294756,  0.13705244],
#        [ 0.83378748,  0.16621252],
#        [ 0.87167897,  0.12832103],
#        [ 0.75202603,  0.24797397],
#        [ 0.13289408,  0.86710592],
#        [ 0.44235959,  0.55764041],
#        [ 0.6944744 ,  0.3055256 ],
#        [ 0.39818017,  0.60181983],
#        [ 0.66179731,  0.33820269],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.85374939,  0.14625061],
#        [ 0.10798638,  0.89201362],
#        [ 0.85374939,  0.14625061],
#        [ 0.28616122,  0.71383878],
#        [ 0.86294756,  0.13705244],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.40131634,  0.59868366],
#        [ 0.86294756,  0.13705244],
#        [ 0.39818017,  0.60181983],
#        [ 0.84800935,  0.15199065],
#        [ 0.83729032,  0.16270968],
#        [ 0.68952153,  0.31047847],
#        [ 0.10136003,  0.89863997],
#        [ 0.86294756,  0.13705244],
#        [ 0.87167897,  0.12832103],
#        [ 0.65045985,  0.34954015],
#        [ 0.83549982,  0.16450018],
#        [ 0.74571922,  0.25428078],
#        [ 0.78854481,  0.21145519],
#        [ 0.13481799,  0.86518201],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.0910063 ,  0.9089937 ],
#        [ 0.59705523,  0.40294477],
#        [ 0.87167897,  0.12832103],
#        [ 0.83378748,  0.16621252],
#        [ 0.6944744 ,  0.3055256 ],
#        [ 0.11124749,  0.88875251],
#        [ 0.75097817,  0.24902183],
#        [ 0.09426054,  0.90573946],
#        [ 0.46801119,  0.53198881],
#        [ 0.09630074,  0.90369926],
#        [ 0.80089441,  0.19910559],
#        [ 0.59705523,  0.40294477],
#        [ 0.86064927,  0.13935073],
#        [ 0.86064927,  0.13935073],
#        [ 0.87167897,  0.12832103],
#        [ 0.87167897,  0.12832103],
#        [ 0.85374939,  0.14625061],
#        [ 0.13481799,  0.86518201],
#        [ 0.86294756,  0.13705244],
#        [ 0.83378748,  0.16621252],
#        [ 0.86294756,  0.13705244],
#        [ 0.09426054,  0.90573946],
#        [ 0.36155759,  0.63844241],
#        [ 0.81617808,  0.18382192],
#        [ 0.87167897,  0.12832103],
#        [ 0.85863717,  0.14136283],
#        [ 0.87167897,  0.12832103],
#        [ 0.44235959,  0.55764041],
#        [ 0.84162161,  0.15837839],
#        [ 0.65045985,  0.34954015],
#        [ 0.87167897,  0.12832103],
#        [ 0.09909903,  0.90090097],
#        [ 0.31228846,  0.68771154],
#        [ 0.83298663,  0.16701337],
#        [ 0.11124749,  0.88875251],
#        [ 0.84641365,  0.15358635],
#        [ 0.83378748,  0.16621252],
#        [ 0.83378748,  0.16621252],
#        [ 0.84641365,  0.15358635],
#        [ 0.57526665,  0.42473335],
#        [ 0.16103069,  0.83896931],
#        [ 0.39818017,  0.60181983],
#        [ 0.40131634,  0.59868366],
#        [ 0.32514676,  0.67485324],
#        [ 0.87167897,  0.12832103],
#        [ 0.87167897,  0.12832103],
#        [ 0.66967572,  0.33032428],
#        [ 0.83298663,  0.16701337],
#        [ 0.85374939,  0.14625061],
#        [ 0.6944744 ,  0.3055256 ],
#        [ 0.53830552,  0.46169448],
#        [ 0.83298663,  0.16701337],
#        [ 0.66967572,  0.33032428],
#        [ 0.86064927,  0.13935073],
#        [ 0.86294756,  0.13705244],
#        [ 0.09414077,  0.90585923],
#        [ 0.81232261,  0.18767739],
#        [ 0.6944744 ,  0.3055256 ],
#        [ 0.86294756,  0.13705244],
#        [ 0.87167897,  0.12832103],
#        [ 0.82800224,  0.17199776],
#        [ 0.83378748,  0.16621252],
#        [ 0.86064927,  0.13935073],
#        [ 0.39818017,  0.60181983],
#        [ 0.14110548,  0.85889452],
#        [ 0.61748048,  0.38251952],
#        [ 0.19324379,  0.80675621],
#        [ 0.71077787,  0.28922213],
#        [ 0.66038871,  0.33961129],
#        [ 0.84162161,  0.15837839],
#        [ 0.8221596 ,  0.1778404 ],
#        [ 0.87167897,  0.12832103],
#        [ 0.39818017,  0.60181983],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.3443401 ,  0.6556599 ],
#        [ 0.61963147,  0.38036853],
#        [ 0.82583554,  0.17416446],
#        [ 0.86294756,  0.13705244],
#        [ 0.75097817,  0.24902183],
#        [ 0.86294756,  0.13705244],
#        [ 0.8221596 ,  0.1778404 ],
#        [ 0.83729032,  0.16270968],
#        [ 0.6944744 ,  0.3055256 ],
#        [ 0.0857372 ,  0.9142628 ],
#        [ 0.86294756,  0.13705244],
#        [ 0.10747638,  0.89252362],
#        [ 0.65045985,  0.34954015],
#        [ 0.83378748,  0.16621252],
#        [ 0.83729032,  0.16270968],
#        [ 0.0910063 ,  0.9089937 ],
#        [ 0.67600318,  0.32399682],
#        [ 0.83298663,  0.16701337],
#        [ 0.34681884,  0.65318116],
#        [ 0.86294756,  0.13705244],
#        [ 0.79084015,  0.20915985],
#        [ 0.83729032,  0.16270968],
#        [ 0.83298663,  0.16701337],
#        [ 0.75097817,  0.24902183],
#        [ 0.83298663,  0.16701337],
#        [ 0.82583554,  0.17416446],
#        [ 0.87167897,  0.12832103],
#        [ 0.75202603,  0.24797397],
#        [ 0.10885456,  0.89114544],
#        [ 0.84800935,  0.15199065],
#        [ 0.38638105,  0.61361895],
#        [ 0.83729032,  0.16270968],
#        [ 0.35453723,  0.64546277],
#        [ 0.83729032,  0.16270968],
#        [ 0.09426054,  0.90573946],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.84641365,  0.15358635],
#        [ 0.75202603,  0.24797397],
#        [ 0.68952153,  0.31047847],
#        [ 0.32514676,  0.67485324],
#        [ 0.79084015,  0.20915985],
#        [ 0.1213454 ,  0.8786546 ],
#        [ 0.87167897,  0.12832103],
#        [ 0.87167897,  0.12832103],
#        [ 0.35252016,  0.64747984],
#        [ 0.78664905,  0.21335095],
#        [ 0.1050949 ,  0.8949051 ],
#        [ 0.09426054,  0.90573946],
#        [ 0.86064927,  0.13935073],
#        [ 0.09909903,  0.90090097],
#        [ 0.73774885,  0.26225115],
#        [ 0.82800224,  0.17199776],
#        [ 0.71387655,  0.28612345],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.81617808,  0.18382192],
#        [ 0.84641365,  0.15358635],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.85863717,  0.14136283],
#        [ 0.83729032,  0.16270968],
#        [ 0.09370959,  0.90629041],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.57526665,  0.42473335],
#        [ 0.84641365,  0.15358635],
#        [ 0.73371782,  0.26628218],
#        [ 0.6624288 ,  0.3375712 ],
#        [ 0.87167897,  0.12832103],
#        [ 0.86294756,  0.13705244],
#        [ 0.47425824,  0.52574176],
#        [ 0.35252016,  0.64747984],
#        [ 0.83729032,  0.16270968],
#        [ 0.0904353 ,  0.9095647 ],
#        [ 0.86294756,  0.13705244],
#        [ 0.8501624 ,  0.1498376 ],
#        [ 0.86294756,  0.13705244],
#        [ 0.71124912,  0.28875088],
#        [ 0.66967572,  0.33032428],
#        [ 0.0857372 ,  0.9142628 ],
#        [ 0.52241285,  0.47758715],
#        [ 0.84641365,  0.15358635],
#        [ 0.85913305,  0.14086695],
#        [ 0.10136003,  0.89863997],
#        [ 0.86294756,  0.13705244],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.86294756,  0.13705244],
#        [ 0.87167897,  0.12832103],
#        [ 0.0857372 ,  0.9142628 ],
#        [ 0.83378748,  0.16621252],
#        [ 0.09909903,  0.90090097],
#        [ 0.68004757,  0.31995243],
#        [ 0.67600318,  0.32399682],
#        [ 0.70532769,  0.29467231],
#        [ 0.84641365,  0.15358635],
#        [ 0.59705523,  0.40294477],
#        [ 0.39818017,  0.60181983],
#        [ 0.36495223,  0.63504777],
#        [ 0.39818017,  0.60181983],
#        [ 0.0857372 ,  0.9142628 ],
#        [ 0.44235959,  0.55764041],
#        [ 0.85374939,  0.14625061],
#        [ 0.0837922 ,  0.9162078 ],
#        [ 0.87167897,  0.12832103],
#        [ 0.85374939,  0.14625061],
#        [ 0.81232261,  0.18767739]])

# %%
survival = []
for x in output:
    survival.append(x[1])
survival_predictions = clean_test.copy()

# %%
survive_perc = pd.Series(survival, index=survival_predictions.index)
survival_predictions['survive_perc'] = survive_perc
survival_predictions['Survived'] = survival_predictions['survive_perc'].apply(lambda x: 1 if x>= 0.5 else 0)
survival_predictions['PassengerId'] = survival_predictions.index

# %%
survival_predictions.head().T
# Out:
# PassengerId          892         893         894         895         896
# Pclass          3.000000    3.000000    2.000000    3.000000    3.000000
# Sex             1.000000    0.000000    1.000000    1.000000    0.000000
# Age            34.500000   47.000000   62.000000   27.000000   22.000000
# SibSp           0.000000    1.000000    0.000000    0.000000    1.000000
# Parch           0.000000    0.000000    0.000000    0.000000    1.000000
# Fare            7.829200    7.000000    9.687500    8.662500   12.287500
# Embarked        0.000000    1.000000    0.000000    1.000000    1.000000
# survive_perc    0.128321    0.397377    0.139351    0.139351    0.606278
# Survived        0.000000    0.000000    0.000000    0.000000    1.000000
# PassengerId   892.000000  893.000000  894.000000  895.000000  896.000000

# %%
output_df = survival_predictions[['PassengerId','Survived']]

# %%
output_df.head().T
# Out:
# PassengerId  892  893  894  895  896
# PassengerId  892  893  894  895  896
# Survived       0    0    0    0    1

# %%
output_df.to_csv('gradient2.csv', index=False)
